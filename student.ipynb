# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name: Brian Kimutai Siele
# * Student pace: full time
# * Instructor name: Mwikali  MaryAnn
# * Blog post URL:https://public.tableau.com/app/profile/brian.siele/viz/ProjectPhase1Tableau/FinalProjectPhase1tableauanalysis?publish=yes

# %% [markdown]
# **INTRODUCTION.**
# The aircraft industry has many options such as; the dimensions, functionality, cost, and safety.In this analysis the point is to investigate the safety and wellbeing of various aircrafts utilizing the accidents data from the Aviation Data.csv.

# %% [markdown]
# ##  Business Understanding
#
# **Problem statement** - Identifying the least risky aircraft to launch the company's new venture at a reasonable and fair price. Moreover, to achieve a successful entry into the market.
# **Key Stakeholders** - Stakeholders will be of wide range.
# Internal Company stakeholders, potential investors External government policies
#
# **Responsibility** - Acclimating to the aviation sector successfully and selecting an aircrafts with the lowest risk.
# **Resources**- Industry reports, budget, data on aircraft safety and expert consultations.
# **Risks** - Possibility of financial loss, accidents involving safety.

# %% [markdown]
# ## Project Goal
# My project aim is to find variables that make an airplane the safest and provide business recommendations based on these findings.This data comes from Kaggle
# https://www.kaggle.com/datasets/khsamaha/aviation-accident-database-synopses

# %% [markdown]
# ### Data Understanding
#
# My project entails information that has previously been collected by different data scientists. The data is stored in **Kaggle**  and is stored in a **csv format**. When I read the data to my notebook using pandas library, I get a dataframe with 90348 rows and 31 columns. From a brief look at the dataframe, we realize that the information we are dealing with is from investigation of aircraft accidents. I have both categorical and continuous data , with the former making the most part of our data.

# %% [markdown]
# ## Dataset Overview
# Summary: The dataset contains90348 rows and 31 columns  .Data points include the number of engines, seveirty of passenger injuries, severity of aircraft damage,and more which are located in the column.
#
# Important Data Columns:
#
# Aircraft Make and Model: Information about the specific make and model of the aircraft involved in each incident.
#
# Aircraft Damage: The severity of the damage to the aircraft
#
# Severity of Injuries: A count for each incident on the number of uninjured, minor, serious, and fatal injuries.
#
# Engine Type: The type of engine on the aircraft
#
# Num of Engines: The number of engines on an airplane. The mean is 1 but can range from 1 - 8.

# %%
#Import necessary packages

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import seaborn as sb
sns.set(style='darkgrid')
from warnings import filterwarnings
filterwarnings("ignore")

# %matplotlib inline

# %%
#Load and print head of Aviation Datasets ('AviationData.csv', 'USState_Codes.csv')

df = pd.read_csv('data/Aviation_Data.csv', encoding='ISO-8859-1', low_memory=False)

df
# Out:
#              Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0      20001218X45444           Accident      SEA87LA080  1948-10-24
# 1      20001218X45447           Accident      LAX94LA336  1962-07-19
# 2      20061025X01555           Accident      NYC07LA005  1974-08-30
# 3      20001218X45448           Accident      LAX96LA321  1977-06-19
# 4      20041105X01764           Accident      CHI79FA064  1979-08-02
# ...               ...                ...             ...         ...
# 90343  20221227106491           Accident      ERA23LA093  2022-12-26
# 90344  20221227106494           Accident      ERA23LA095  2022-12-26
# 90345  20221227106497           Accident      WPR23LA075  2022-12-26
# 90346  20221227106498           Accident      WPR23LA076  2022-12-26
# 90347  20221230106513           Accident      ERA23LA097  2022-12-29
#
#               Location        Country   Latitude   Longitude Airport.Code  \
# ...

# %%
# Evaluate the column headers

df.columns
# Out:
# Index(['Event.Id', 'Investigation.Type', 'Accident.Number', 'Event.Date',
#        'Location', 'Country', 'Latitude', 'Longitude', 'Airport.Code',
#        'Airport.Name', 'Injury.Severity', 'Aircraft.damage',
#        'Aircraft.Category', 'Registration.Number', 'Make', 'Model',
#        'Amateur.Built', 'Number.of.Engines', 'Engine.Type', 'FAR.Description',
#        'Schedule', 'Purpose.of.flight', 'Air.carrier', 'Total.Fatal.Injuries',
#        'Total.Serious.Injuries', 'Total.Minor.Injuries', 'Total.Uninjured',
#        'Weather.Condition', 'Broad.phase.of.flight', 'Report.Status',
#        'Publication.Date'],
#       dtype='object')

# %%
# understand the data types, counts, and null values 

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90348 entries, 0 to 90347
# Data columns (total 31 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Event.Id                88889 non-null  object
#  1   Investigation.Type      90348 non-null  object
#  2   Accident.Number         88889 non-null  object
#  3   Event.Date              88889 non-null  object
#  4   Location                88837 non-null  object
#  5   Country                 88663 non-null  object
#  6   Latitude                34382 non-null  object
#  7   Longitude               34373 non-null  object
#  8   Airport.Code            50249 non-null  object
#  9   Airport.Name            52790 non-null  object
#  10  Injury.Severity         87889 non-null  object
#  11  Aircraft.damage         85695 non-null  object
#  12  Aircraft.Category       32287 non-null  object
#  13  Registration.Number     87572 non-null  object
# ...

# %%
# Get descriptive statistics for the dataset

df.describe().T
# Out:
#                           count      mean        std  min  25%  50%  75%  \
# Number.of.Engines       82805.0  1.146585   0.446510  0.0  1.0  1.0  1.0
# Total.Fatal.Injuries    77488.0  0.647855   5.485960  0.0  0.0  0.0  0.0
# Total.Serious.Injuries  76379.0  0.279881   1.544084  0.0  0.0  0.0  0.0
# Total.Minor.Injuries    76956.0  0.357061   2.235625  0.0  0.0  0.0  0.0
# Total.Uninjured         82977.0  5.325440  27.913634  0.0  0.0  1.0  2.0
#
#                           max
# Number.of.Engines         8.0
# Total.Fatal.Injuries    349.0
# Total.Serious.Injuries  161.0
# Total.Minor.Injuries    380.0
# Total.Uninjured         699.0

# %% [markdown]
# # Data Cleaning

# %%
#Identify missing values across dataframe columns 

df.isna().sum()/len(df)*100
# Out:
# Event.Id                   1.614867
# Investigation.Type         0.000000
# Accident.Number            1.614867
# Event.Date                 1.614867
# Location                   1.672422
# Country                    1.865011
# Latitude                  61.944924
# Longitude                 61.954886
# Airport.Code              44.382831
# Airport.Name              41.570372
# Injury.Severity            2.721698
# Aircraft.damage            5.150086
# Aircraft.Category         64.263736
# Registration.Number        3.072564
# Make                       1.684597
# Model                      1.716695
# Amateur.Built              1.727764
# Number.of.Engines          8.348829
# Engine.Type                9.447913
# FAR.Description           64.555939
# Schedule                  86.073848
# Purpose.of.flight          8.468367
# Air.carrier               81.573471
# Total.Fatal.Injuries      14.233851
# Total.Serious.Injuries    15.461327
# Total.Minor.Injuries      14.822686
# ...

# %%
# Copy of my Original data
original_data = df.copy()

# %%
df = original_data.copy()

# %%
#Identify columns with more than 50% of missing data and add them to a list

columns_to_drop=[]
for x in df:
    if (df[x].isna().sum() / len(df[x])) * 100 > 50:
        columns_to_drop.append(x)
print(columns_to_drop)
# Out:
# ['Latitude', 'Longitude', 'Aircraft.Category', 'FAR.Description', 'Schedule', 'Air.carrier']

# %%
#Drop columns from dataframe that are missing too much data
df= df.drop(columns= columns_to_drop)
df
# Out:
#              Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0      20001218X45444           Accident      SEA87LA080  1948-10-24
# 1      20001218X45447           Accident      LAX94LA336  1962-07-19
# 2      20061025X01555           Accident      NYC07LA005  1974-08-30
# 3      20001218X45448           Accident      LAX96LA321  1977-06-19
# 4      20041105X01764           Accident      CHI79FA064  1979-08-02
# ...               ...                ...             ...         ...
# 90343  20221227106491           Accident      ERA23LA093  2022-12-26
# 90344  20221227106494           Accident      ERA23LA095  2022-12-26
# 90345  20221227106497           Accident      WPR23LA075  2022-12-26
# 90346  20221227106498           Accident      WPR23LA076  2022-12-26
# 90347  20221230106513           Accident      ERA23LA097  2022-12-29
#
#               Location        Country Airport.Code Airport.Name  \
# 0      MOOSE CREEK, ID  United States          NaN          NaN
# ...

# %%
# idenitify irrelevant columns and drop them in this case we will only reamin with columns which will be useful for data analysis
columns =['Investigation.Type','Accident.Number', 'Airport.Code', 'Airport.Name','Registration.Number']
df=df.drop(columns,axis=1)
df
# Out:
#              Event.Id  Event.Date         Location        Country  \
# 0      20001218X45444  1948-10-24  MOOSE CREEK, ID  United States
# 1      20001218X45447  1962-07-19   BRIDGEPORT, CA  United States
# 2      20061025X01555  1974-08-30    Saltville, VA  United States
# 3      20001218X45448  1977-06-19       EUREKA, CA  United States
# 4      20041105X01764  1979-08-02       Canton, OH  United States
# ...               ...         ...              ...            ...
# 90343  20221227106491  2022-12-26    Annapolis, MD  United States
# 90344  20221227106494  2022-12-26      Hampton, NH  United States
# 90345  20221227106497  2022-12-26       Payson, AZ  United States
# 90346  20221227106498  2022-12-26       Morgan, UT  United States
# 90347  20221230106513  2022-12-29       Athens, GA  United States
#
#       Injury.Severity Aircraft.damage                        Make      Model  \
# 0            Fatal(2)       Destroyed                     Stinson      108-3
# ...

# %%
#Calculating the mode of the columns having numerical datatypes.
modes = df[['Number.of.Engines', 'Total.Fatal.Injuries', 'Total.Serious.Injuries', 'Total.Minor.Injuries', 'Total.Uninjured']].mode()
modes
# Out:
#    Number.of.Engines  Total.Fatal.Injuries  Total.Serious.Injuries  \
# 0                1.0                   0.0                     0.0
#
#    Total.Minor.Injuries  Total.Uninjured
# 0                   0.0              0.0

# %%
#fill the numerical values with mode
for column in ['Number.of.Engines', 'Total.Fatal.Injuries', 'Total.Serious.Injuries', 'Total.Minor.Injuries', 'Total.Uninjured']:
    df[column].fillna(df[column].mode()[0], inplace=True)

# %%
#fill the missing values in the reamining columns using forward and backward fill
df.fillna(method='ffill').fillna(method='bfill')
# Out:
#              Event.Id  Event.Date         Location        Country  \
# 0      20001218X45444  1948-10-24  MOOSE CREEK, ID  United States
# 1      20001218X45447  1962-07-19   BRIDGEPORT, CA  United States
# 2      20061025X01555  1974-08-30    Saltville, VA  United States
# 3      20001218X45448  1977-06-19       EUREKA, CA  United States
# 4      20041105X01764  1979-08-02       Canton, OH  United States
# ...               ...         ...              ...            ...
# 90343  20221227106491  2022-12-26    Annapolis, MD  United States
# 90344  20221227106494  2022-12-26      Hampton, NH  United States
# 90345  20221227106497  2022-12-26       Payson, AZ  United States
# 90346  20221227106498  2022-12-26       Morgan, UT  United States
# 90347  20221230106513  2022-12-29       Athens, GA  United States
#
#       Injury.Severity Aircraft.damage                        Make      Model  \
# 0            Fatal(2)       Destroyed                     Stinson      108-3
# ...

# %%
df.isna().sum()/len(df)*100
# Out:
# Event.Id                   1.614867
# Event.Date                 1.614867
# Location                   1.672422
# Country                    1.865011
# Injury.Severity            2.721698
# Aircraft.damage            5.150086
# Make                       1.684597
# Model                      1.716695
# Amateur.Built              1.727764
# Number.of.Engines          0.000000
# Engine.Type                9.447913
# Purpose.of.flight          8.468367
# Total.Fatal.Injuries       0.000000
# Total.Serious.Injuries     0.000000
# Total.Minor.Injuries       0.000000
# Total.Uninjured            0.000000
# Weather.Condition          6.586753
# Broad.phase.of.flight     31.681941
# Report.Status              8.677558
# Publication.Date          18.471909
# dtype: float64

# %%
# Converting 'Event.Date' and 'Publication.Date' to datetime datatype
df['Event.Date'] = pd.to_datetime(df['Event.Date'], errors='coerce')
df['Publication.Date'] = pd.to_datetime(df['Publication.Date'], errors='coerce', format='%d-%m-%Y')

# %%
#Reviewing the column datatypes again.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90348 entries, 0 to 90347
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Event.Id                88889 non-null  object
#  1   Event.Date              88889 non-null  datetime64[ns]
#  2   Location                88837 non-null  object
#  3   Country                 88663 non-null  object
#  4   Injury.Severity         87889 non-null  object
#  5   Aircraft.damage         85695 non-null  object
#  6   Make                    88826 non-null  object
#  7   Model                   88797 non-null  object
#  8   Amateur.Built           88787 non-null  object
#  9   Number.of.Engines       90348 non-null  float64
#  10  Engine.Type             81812 non-null  object
#  11  Purpose.of.flight       82697 non-null  object
#  12  Total.Fatal.Injuries    90348 non-null  float64
#  13  Total.Serious.Injuries  90348 non-null  float64
# ...

# %%
# inspecting different airplanes makes
df['Make'].value_counts()
# Out:
# Cessna          22227
# Piper           12029
# CESSNA           4922
# Beech            4330
# PIPER            2841
#                 ...
# Gildersleeve        1
# Robert Judd         1
# Tierra Ii           1
# Teratron            1
# SIERRA              1
# Name: Make, Length: 8237, dtype: int64

# %%
#clean the data in make
df['Make']=df['Make'].str.title()

# %%
# inspecting different types of Aircraft.damage
damage_count=df['Aircraft.damage'].value_counts
damage_count
# Out:
# <bound method IndexOpsMixin.value_counts of 0          Destroyed
# 1          Destroyed
# 2          Destroyed
# 3          Destroyed
# 4          Destroyed
#             ...
# 90343            NaN
# 90344            NaN
# 90345    Substantial
# 90346            NaN
# 90347            NaN
# Name: Aircraft.damage, Length: 90348, dtype: object>

# %%
#Explore different values in Weather Condition column
df['Weather.Condition'].value_counts()
# Out:
# VMC    77303
# IMC     5976
# UNK      856
# Unk      262
# Name: Weather.Condition, dtype: int64

# %%
#Clean values in Weather Condition column
df['Weather.Condition'].str.upper()
# Out:
# 0        UNK
# 1        UNK
# 2        IMC
# 3        IMC
# 4        VMC
#         ...
# 90343    NaN
# 90344    NaN
# 90345    VMC
# 90346    NaN
# 90347    NaN
# Name: Weather.Condition, Length: 90348, dtype: object

# %%
#Explore different values in Weather Condition column
df['Engine.Type'].value_counts()
# Out:
# Reciprocating      69530
# Turbo Shaft         3609
# Turbo Prop          3391
# Turbo Fan           2481
# Unknown             2051
# Turbo Jet            703
# None                  19
# Geared Turbofan       12
# Electric              10
# LR                     2
# NONE                   2
# UNK                    1
# Hybrid Rocket          1
# Name: Engine.Type, dtype: int64

# %%
 #Creating a copy of my clean dataset
cleaned_df = df.copy()

# %%
# Save the cleaned DataFrame to a CSV file
cleaned_df.to_csv('cleaned_Aviation_data.csv', index=False)

# %%
df = cleaned_df.copy()

# %% [markdown]
# ### the data is clean now and available forEDA

# %% [markdown]
# # Exploratory Data Analysis /Data Visualization

# %% [markdown]
# # Count the number of Accidents as per Countries

# %%
# Count of Accidents as per Countries
accidents =df['Country'].groupby(df['Country']).count()
accidents
# Out:
# Country
# ATLANTIC OCEAN    81
# AY                 1
# Afghanistan       14
# Albania            1
# Algeria            2
#                   ..
# West Indies       11
# Wolseley           1
# Yemen              1
# Zambia             2
# Zimbabwe           6
# Name: Country, Length: 219, dtype: int64

# %% [markdown]
# # Plot 1: Distribution of Accidents in different Countries (Count of Accidents which is more than 200)

# %%
fig = plt.figure(figsize=(15,10))
accidents_Count = accidents[df['Country'].groupby(df['Country']).count() > 200]
accidents_Count_df = pd.DataFrame({'Country':accidents_Count.index,'Count':accidents_Count.values})
plt.bar(accidents_Count_df['Country'], height = accidents_Count_df['Count'], color='red')
plt.xticks(rotation=90)
plt.xlabel("Country", size=15)
plt.ylabel("Count of Accidents", size=10)
y=accidents_Count_df['Count']
for i,v in enumerate(y):
    plt.text(x=i, y=v, s=str(v), horizontalalignment='center', size=15)
plt.title("Distribution of Accidents wrt Countries", size=20)
plt.show()

# %% [markdown]
# ### from the above plot, there are 7 countries namely Australia, Bahamas, Brazil, Canada, Mexico, United Kingdom and the United States which have count of accidents more than 200. Also, most of the accidents have occurred in the US only with staggering 82,248count

# %% [markdown]
# # Plot 2: Top 20 Companies which are involved in accidents

# %%
# Evaluate the Companies which are common in accidents

plt.figure(figsize=(15,10))
df['Make'].str.upper().value_counts().sort_values(ascending=False)[:20].plot(kind='bar', color='Green')
plt.xticks(rotation=90)
plt.xlabel("Make", size=15)
plt.ylabel("Count of Accidents", size=15)
plt.title("Top 20 Aircraft Companies in the United States", size=20)
y=df['Make'].str.upper().value_counts().sort_values(ascending=False)[:20]
for i, v in enumerate(y):
    plt.text(i, v, str(v), fontsize=15, style='oblique', horizontalalignment='center')
plt.show()

# %% [markdown]
# ### In this plot, we are analysing the top 20  companies which are involved in most of the accidents. 'Cessna' has 25,853 accidents in the bucket whereas 'Piper' and ' Beech' have 14,168 and 2285 accidents, respectively.

# %% [markdown]
# # Plot 3: What was the Phase of Flight and Weather Conditions when accident took place?

# %%
plt.figure(figsize=(15,10))
splot = sns.countplot(data=df, x="Broad.phase.of.flight", hue='Weather.Condition', edgecolor=(0,0,0), linewidth=1, palette='Reds')
plt.xticks(rotation=90)
plt.xlabel("Broad Phase of Flight", size=15)
plt.ylabel("Number of Occurrences", size=15)
plt.title("What was the Phase of Flight when Accident took place?", size=20)
for p in splot.patches:
    splot.annotate(format(p.get_height()), (p.get_x() + p.get_width() / 2., 
    p.get_height()), ha = 'center', va = 'bottom', xytext = (0, 10), textcoords = 'offset points', rotation=90, size=11.5)
plt.show()

# %% [markdown]
# ### This plot illustrates that most of the accidents took place when aircraft was either Landing or Taking off. 14,902 accidents took place when the airplace was Landing and the weather conditions were clear for flight. About 15,385 accidents took place during take off with clear weather conditions.

# %% [markdown]
# # Plot 4: What was the Engine Type of Fatal or Non-Fatal accidents?

# %%
cplot = sns.catplot(x="Engine.Type", col="Injury.Severity", kind="count", col_wrap=2,
            data=df[df['Injury.Severity'].isin(['Fatal','Non-Fatal'])], height=4,
                 legend_out=True, size=8, palette="Set3", edgecolor=(0,0,0))
cplot.set_xticklabels(rotation=90)
cplot.fig.suptitle("What was the Engine Type of Fatal or Non-Fatal accidents?", size=20)
cplot.fig.subplots_adjust(top=.9)
cplot.set_titles("Injury Severity Type is {col_name}")
cplot.set(ylim=[0,65000])
for ax in cplot.axes.ravel():
    for p in ax.patches:
        ax.annotate(format(p.get_height()), (p.get_x() + p.get_width() / 2, 
        p.get_height()), ha = 'center', va = 'bottom', xytext = (0, 10), textcoords = 'offset points', rotation=90, size=12)
plt.show()

# %% [markdown]
# ##### Post analysis of above two plots, it can said that most of the Fatal or Non-Fatal accident occurred for Engine Type 'Reciprocating'. For Fatal, count is 13,068 whereas for Non-Fatal, count is around 54,310.

# %% [markdown]
# # Plot 5: What is the total number of fatal injuries?

# %%
#Calculating total number of fatal injuries.
df['Total.Injuries'] = df['Total.Fatal.Injuries'] + df['Total.Serious.Injuries'] + df['Total.Minor.Injuries']

# Sort by total injuries and select the top 20 locations
top_20_injuries = df[['Location', 'Total.Injuries']].sort_values(by='Total.Injuries', ascending=False).head(20)

#Plotting bar plot.
plt.figure(figsize=(12, 8))
sns.barplot(x='Total.Injuries', y='Location', data=top_20_injuries, palette='viridis')
plt.xlabel('Total Number of Injuries')
plt.ylabel('Location')
plt.title('Top 20 Locations by Total Number of Injuries')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# #### from the above plot MONTREAL,canada has about 370 total number of injuries while San Franciso ,CA has the less total number of injuries 180

# %% [markdown]
# # Plot 6: Which Aircraft categories had uninjured survivors after an accident?

# %%
# Checking which Aircraft categories had uninjured survivors after an accident.
aircraft_category= ['Airplane','Balloon','Blimp','Glider','Gyrocraft','Helicopter','Missing','Powered Parachute','Powered-Lift','Ultralight','Unknown','WSFT','Weight-Shift']
total_uninjured= [6.192237,3.65368,1.25,0.722441,0.520231,1.165116,4.698989,0.252747,0.8,0.466667,1.285714,0.111111,0.291925]

fig, ax = plt.subplots(figsize=(12,8))
ax.bar(aircraft_category, total_uninjured)
ax.set_xlabel('aircraft_category')
ax.set_ylabel('Total mean of uninjured')
ax.set_title('Aircraft categories that had survivors')
plt.xticks(Rotation=60)
plt.show()

# %% [markdown]
# # Conclusion

# %% [markdown]
#  ## Based on the analysis above we have discovered that:
# #### 1. Most of the aviation accidents have taken place in the United States.
# #### 2. CESSNA and PIPER are Companies which manufactured aircrafts that are involved in accidents as per this dataset..
# #### 3. Most of the aviation incidents have taken place during Takeoff and Landing. Most of the times, weather conditions were favorable for flight.
# #### 4. Engine Type of both Fatal and Non-Fatal accidents was Reciprocating for most of the accidents.
